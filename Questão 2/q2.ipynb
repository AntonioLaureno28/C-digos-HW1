# %% [markdown]
# # Questão 2

# %% [markdown]
# ## 2.1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def modo_1(t):
    return np.exp(-3*t)
def modo_2(t):
    return t*np.exp(-3*t)

# %%
t = np.linspace(0,5,20)
y_1 = modo_1(t)
y_2 = modo_2(t)

# %%
plt.plot(t,y_1)
plt.xlabel("Tempo(s)")
plt.ylabel("Modo 1")
# Out:
# Text(0, 0.5, 'Modo 1')

# %%
plt.plot(t,y_2)
plt.xlabel("Tempo(s)")
plt.ylabel("Modo 2")
# Out:
# Text(0, 0.5, 'Modo 2')
